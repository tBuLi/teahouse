# %% [markdown]
# # Writing high(ish) performance code with Kingdon and Numba
#
# In this document we will demonstrate how easy it is to compose together the fundamental (binary and unary) operators that kingdon supplies out of the box, while maintaining good performance.
#
# The example used is inspired by that of [`clifford`](https://clifford.readthedocs.io/en/latest/tutorials/PerformanceCliffordTutorial.html) to allow for comparison of both syntax and performance. In order to make the performance comparison fair, we will run both versions within this document, such that both examples are run on the same machine.
#
# First we will run `kingdon` with `numba` enabled and while leveraging the sparseness in the example, to get the best speeds possible. Then we will run the `clifford` equivalent. Lastly, we will run the `kingdon` example again but with a full multivector, to show how the two libraries compare in this case.

# %% [markdown]
# ### Kingdon unchained
#
# First, we run `kingdon` on the example, allowing it to use all of its tricks.
#
# Let's initiate a 3DCGA algebra and create some simple lines.

# %%
# %pip install -q kingdon anywidget clifford numba==0.46
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [746 lines of output]
#   C:\Users\martin.roelfs\AppData\Local\Temp\pip-install-jkpkab2u\numba_24fa23671a3d4a88b64c75588a7d5503\setup.py:96: DeprecationWarning:
#
#     `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#     of the deprecation of `distutils` itself. It will be removed for
#     Python >= 3.12. For older Python versions it will remain present.
#     It is recommended to use `setuptools < 60.0` for those Python versions.
#     For more details, see:
#       https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#     import numpy.distutils.misc_util as np_misc
#   TBB not found
#   OpenMP disabled
#   C:\Users\martin.roelfs\Anaconda3\envs\teahouse\lib\site-packages\setuptools\__init__.py:81: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   running bdist_wheel
#   running build
#   got version from file C:\Users\martin.roelfs\AppData\Local\Temp\pip-install-jkpkab2u\numba_24fa23671a3d4a88b64c75588a7d5503\numba/_version.py {'version': '0.46.0', 'full': 'fed07c578cb1b478ac29a439876da68170738f11'}
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\numba
#   copying numba\analysis.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\appdirs.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\array_analysis.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\bytecode.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\caching.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\callwrapper.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\ccallback.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\cffi_support.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\cgutils.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\charseq.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\compiler.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\compiler_lock.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\compiler_machinery.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\config.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\consts.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\controlflow.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\ctypes_support.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\dataflow.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\debuginfo.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\decorators.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\dictobject.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\dispatcher.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\dummyarray.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\entrypoints.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\errors.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\extending.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\findlib.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\funcdesc.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\generators.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\inline_closurecall.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\interpreter.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\io_support.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\ir.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\ir_utils.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\itanium_mangler.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\listobject.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\lowering.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\macro.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\npdatetime.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\numba_entry.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\numpy_extensions.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\numpy_support.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\object_mode_passes.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\parfor.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\postproc.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\pretty_annotate.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\pylowering.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\pythonapi.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\runtests.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\serialize.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\sigutils.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\six.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\special.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\stencil.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\stencilparfor.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\tracing.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\transforms.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\typedobjectutils.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\typed_passes.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\typeinfer.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\unicode.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\unicode_support.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\unittest_support.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\untyped_passes.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\utils.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\withcontexts.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_runtests.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_version.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\__init__.py -> build\lib.win-amd64-cpython-310\numba
#   copying numba\__main__.py -> build\lib.win-amd64-cpython-310\numba
#   creating build\lib.win-amd64-cpython-310\numba\annotations
#   copying numba\annotations\type_annotations.py -> build\lib.win-amd64-cpython-310\numba\annotations
#   copying numba\annotations\__init__.py -> build\lib.win-amd64-cpython-310\numba\annotations
#   creating build\lib.win-amd64-cpython-310\numba\cext
#   copying numba\cext\__init__.py -> build\lib.win-amd64-cpython-310\numba\cext
#   creating build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\api.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\args.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\codegen.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\compiler.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\cudadecl.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\cudaimpl.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\cudamath.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\cuda_paths.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\decorators.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\descriptor.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\device_init.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\dispatcher.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\envvars.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\errors.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\initialize.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\intrinsic_wrapper.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\libdevice.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\nvvmutils.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\printimpl.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\random.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\simulator_init.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\stubs.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\target.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\testing.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\vectorizers.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   copying numba\cuda\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda
#   creating build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\autotune.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\devicearray.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\devices.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\driver.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\drvapi.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\enums.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\error.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\libs.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\ndarray.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\nvvm.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   copying numba\cuda\cudadrv\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\cudadrv
#   creating build\lib.win-amd64-cpython-310\numba\cuda\kernels
#   copying numba\cuda\kernels\reduction.py -> build\lib.win-amd64-cpython-310\numba\cuda\kernels
#   copying numba\cuda\kernels\transpose.py -> build\lib.win-amd64-cpython-310\numba\cuda\kernels
#   copying numba\cuda\kernels\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\kernels
#   creating build\lib.win-amd64-cpython-310\numba\cuda\simulator
#   copying numba\cuda\simulator\api.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator
#   copying numba\cuda\simulator\compiler.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator
#   copying numba\cuda\simulator\kernel.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator
#   copying numba\cuda\simulator\kernelapi.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator
#   copying numba\cuda\simulator\reduction.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator
#   copying numba\cuda\simulator\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator
#   creating build\lib.win-amd64-cpython-310\numba\cuda\simulator\cudadrv
#   copying numba\cuda\simulator\cudadrv\devicearray.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator\cudadrv
#   copying numba\cuda\simulator\cudadrv\devices.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator\cudadrv
#   copying numba\cuda\simulator\cudadrv\driver.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator\cudadrv
#   copying numba\cuda\simulator\cudadrv\drvapi.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator\cudadrv
#   copying numba\cuda\simulator\cudadrv\nvvm.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator\cudadrv
#   copying numba\cuda\simulator\cudadrv\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\simulator\cudadrv
#   creating build\lib.win-amd64-cpython-310\numba\cuda\tests
#   copying numba\cuda\tests\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests
#   creating build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_array_attr.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_context_stack.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_cuda_array_slicing.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_cuda_auto_context.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_cuda_devicerecord.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_cuda_driver.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_cuda_libraries.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_cuda_memory.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_cuda_ndarray.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_deallocations.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_detect.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_events.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_host_alloc.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_inline_ptx.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_ir_patch.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_linker.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_nvvm_driver.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_pinned.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_profiler.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_reset_device.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\test_select_device.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   copying numba\cuda\tests\cudadrv\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv
#   creating build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv\data
#   copying numba\cuda\tests\cudadrv\data\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv\data
#   creating build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_alignment.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_array.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_array_args.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_array_methods.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_atomics.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_autojit.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_blackscholes.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_boolean.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_casting.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_complex.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_complex_kernel.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_constmem.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_const_string.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_cuda_array_interface.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_cuda_autojit.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_datetime.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_debug.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_debuginfo.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_deprecation.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_device_func.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_errors.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_exception.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_fastmath.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_forall.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_freevar.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_globals.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_gufunc.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_gufunc_scalar.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_gufunc_scheduling.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_idiv.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_inspect.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_intrinsics.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_ipc.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_lang.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_laplace.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_localmem.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_macro.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_mandel.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_math.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_matmul.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_minmax.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_montecarlo.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_multigpu.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_multiprocessing.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_multithreads.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_nondet.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_operator.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_powi.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_print.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_py2_div_issue.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_random.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_record_dtype.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_reduction.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_retrieve_autoconverted_arrays.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_serialize.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_slicing.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_sm.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_sync.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_transpose.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_userexc.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_vectorize.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_vectorize_complex.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_vectorize_decor.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_vectorize_device.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_vectorize_scalar_arg.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\test_warp_ops.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   copying numba\cuda\tests\cudapy\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudapy
#   creating build\lib.win-amd64-cpython-310\numba\cuda\tests\cudasim
#   copying numba\cuda\tests\cudasim\support.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudasim
#   copying numba\cuda\tests\cudasim\test_cudasim_issues.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudasim
#   copying numba\cuda\tests\cudasim\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudasim
#   creating build\lib.win-amd64-cpython-310\numba\cuda\tests\nocuda
#   copying numba\cuda\tests\nocuda\test_library_lookup.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\nocuda
#   copying numba\cuda\tests\nocuda\test_nvvm.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\nocuda
#   copying numba\cuda\tests\nocuda\__init__.py -> build\lib.win-amd64-cpython-310\numba\cuda\tests\nocuda
#   creating build\lib.win-amd64-cpython-310\numba\datamodel
#   copying numba\datamodel\manager.py -> build\lib.win-amd64-cpython-310\numba\datamodel
#   copying numba\datamodel\models.py -> build\lib.win-amd64-cpython-310\numba\datamodel
#   copying numba\datamodel\packer.py -> build\lib.win-amd64-cpython-310\numba\datamodel
#   copying numba\datamodel\registry.py -> build\lib.win-amd64-cpython-310\numba\datamodel
#   copying numba\datamodel\testing.py -> build\lib.win-amd64-cpython-310\numba\datamodel
#   copying numba\datamodel\__init__.py -> build\lib.win-amd64-cpython-310\numba\datamodel
#   creating build\lib.win-amd64-cpython-310\numba\help
#   copying numba\help\inspector.py -> build\lib.win-amd64-cpython-310\numba\help
#   copying numba\help\__init__.py -> build\lib.win-amd64-cpython-310\numba\help
#   creating build\lib.win-amd64-cpython-310\numba\jitclass
#   copying numba\jitclass\base.py -> build\lib.win-amd64-cpython-310\numba\jitclass
#   copying numba\jitclass\boxing.py -> build\lib.win-amd64-cpython-310\numba\jitclass
#   copying numba\jitclass\decorators.py -> build\lib.win-amd64-cpython-310\numba\jitclass
#   copying numba\jitclass\__init__.py -> build\lib.win-amd64-cpython-310\numba\jitclass
#   creating build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\array_exprs.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\decorators.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\deviceufunc.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\dufunc.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\parallel.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\parfor.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\sigparse.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\ufuncbuilder.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\wrappers.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   copying numba\npyufunc\__init__.py -> build\lib.win-amd64-cpython-310\numba\npyufunc
#   creating build\lib.win-amd64-cpython-310\numba\pycc
#   copying numba\pycc\cc.py -> build\lib.win-amd64-cpython-310\numba\pycc
#   copying numba\pycc\compiler.py -> build\lib.win-amd64-cpython-310\numba\pycc
#   copying numba\pycc\decorators.py -> build\lib.win-amd64-cpython-310\numba\pycc
#   copying numba\pycc\llvm_types.py -> build\lib.win-amd64-cpython-310\numba\pycc
#   copying numba\pycc\platform.py -> build\lib.win-amd64-cpython-310\numba\pycc
#   copying numba\pycc\__init__.py -> build\lib.win-amd64-cpython-310\numba\pycc
#   creating build\lib.win-amd64-cpython-310\numba\rewrites
#   copying numba\rewrites\ir_print.py -> build\lib.win-amd64-cpython-310\numba\rewrites
#   copying numba\rewrites\macros.py -> build\lib.win-amd64-cpython-310\numba\rewrites
#   copying numba\rewrites\registry.py -> build\lib.win-amd64-cpython-310\numba\rewrites
#   copying numba\rewrites\static_binop.py -> build\lib.win-amd64-cpython-310\numba\rewrites
#   copying numba\rewrites\static_getitem.py -> build\lib.win-amd64-cpython-310\numba\rewrites
#   copying numba\rewrites\static_raise.py -> build\lib.win-amd64-cpython-310\numba\rewrites
#   copying numba\rewrites\__init__.py -> build\lib.win-amd64-cpython-310\numba\rewrites
#   creating build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\api.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\codegen.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\compiler.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\decorators.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\descriptor.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\dispatch.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\enums.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\gcn_occupancy.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\hsadecl.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\hsaimpl.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\initialize.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\mathdecl.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\mathimpl.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\stubs.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\target.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\vectorizers.py -> build\lib.win-amd64-cpython-310\numba\roc
#   copying numba\roc\__init__.py -> build\lib.win-amd64-cpython-310\numba\roc
#   creating build\lib.win-amd64-cpython-310\numba\roc\hlc
#   copying numba\roc\hlc\common.py -> build\lib.win-amd64-cpython-310\numba\roc\hlc
#   copying numba\roc\hlc\config.py -> build\lib.win-amd64-cpython-310\numba\roc\hlc
#   copying numba\roc\hlc\hlc.py -> build\lib.win-amd64-cpython-310\numba\roc\hlc
#   copying numba\roc\hlc\libhlc.py -> build\lib.win-amd64-cpython-310\numba\roc\hlc
#   copying numba\roc\hlc\__init__.py -> build\lib.win-amd64-cpython-310\numba\roc\hlc
#   creating build\lib.win-amd64-cpython-310\numba\roc\hsadrv
#   copying numba\roc\hsadrv\devicearray.py -> build\lib.win-amd64-cpython-310\numba\roc\hsadrv
#   copying numba\roc\hsadrv\devices.py -> build\lib.win-amd64-cpython-310\numba\roc\hsadrv
#   copying numba\roc\hsadrv\driver.py -> build\lib.win-amd64-cpython-310\numba\roc\hsadrv
#   copying numba\roc\hsadrv\drvapi.py -> build\lib.win-amd64-cpython-310\numba\roc\hsadrv
#   copying numba\roc\hsadrv\enums.py -> build\lib.win-amd64-cpython-310\numba\roc\hsadrv
#   copying numba\roc\hsadrv\enums_ext.py -> build\lib.win-amd64-cpython-310\numba\roc\hsadrv
#   copying numba\roc\hsadrv\error.py -> build\lib.win-amd64-cpython-310\numba\roc\hsadrv
#   copying numba\roc\hsadrv\__init__.py -> build\lib.win-amd64-cpython-310\numba\roc\hsadrv
#   creating build\lib.win-amd64-cpython-310\numba\roc\tests
#   copying numba\roc\tests\__init__.py -> build\lib.win-amd64-cpython-310\numba\roc\tests
#   creating build\lib.win-amd64-cpython-310\numba\roc\tests\hsadrv
#   copying numba\roc\tests\hsadrv\test_async.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsadrv
#   copying numba\roc\tests\hsadrv\test_driver.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsadrv
#   copying numba\roc\tests\hsadrv\__init__.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsadrv
#   creating build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\run_far_branch.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_async_kernel.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_atomics.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_autojit.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_barrier.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_compiler.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_decorator.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_gufuncbuilding.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_intrinsics.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_large_code.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_linkage.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_math.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_matmul.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_memory.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_occupancy.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_positioning.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_reduction.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_scan.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_simple.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\test_ufuncbuilding.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   copying numba\roc\tests\hsapy\__init__.py -> build\lib.win-amd64-cpython-310\numba\roc\tests\hsapy
#   creating build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\runtime\context.py -> build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\runtime\nrt.py -> build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\runtime\nrtdynmod.py -> build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\runtime\nrtopt.py -> build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\runtime\__init__.py -> build\lib.win-amd64-cpython-310\numba\runtime
#   creating build\lib.win-amd64-cpython-310\numba\scripts
#   copying numba\scripts\generate_lower_listing.py -> build\lib.win-amd64-cpython-310\numba\scripts
#   copying numba\scripts\__init__.py -> build\lib.win-amd64-cpython-310\numba\scripts
#   creating build\lib.win-amd64-cpython-310\numba\servicelib
#   copying numba\servicelib\service.py -> build\lib.win-amd64-cpython-310\numba\servicelib
#   copying numba\servicelib\threadlocal.py -> build\lib.win-amd64-cpython-310\numba\servicelib
#   copying numba\servicelib\__init__.py -> build\lib.win-amd64-cpython-310\numba\servicelib
#   creating build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\arraymath.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\arrayobj.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\base.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\boxing.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\builtins.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\callconv.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\cffiimpl.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\cmathimpl.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\codegen.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\cpu.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\cpu_options.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\descriptors.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\dictimpl.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\enumimpl.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\externals.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\fastmathpass.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\gdb_hook.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\hashing.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\heapq.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\imputils.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\intrinsics.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\iterators.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\linalg.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\listobj.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\literal_dispatch.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\mathimpl.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\mergesort.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\npdatetime.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\npyfuncs.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\npyimpl.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\numbers.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\optional.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\options.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\polynomial.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\printimpl.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\quicksort.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\randomimpl.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\rangeobj.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\registry.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\removerefctpass.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\setobj.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\slicing.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\tupleobj.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\ufunc_db.py -> build\lib.win-amd64-cpython-310\numba\targets
#   copying numba\targets\__init__.py -> build\lib.win-amd64-cpython-310\numba\targets
#   creating build\lib.win-amd64-cpython-310\numba\testing
#   copying numba\testing\ddt.py -> build\lib.win-amd64-cpython-310\numba\testing
#   copying numba\testing\loader.py -> build\lib.win-amd64-cpython-310\numba\testing
#   copying numba\testing\main.py -> build\lib.win-amd64-cpython-310\numba\testing
#   copying numba\testing\notebook.py -> build\lib.win-amd64-cpython-310\numba\testing
#   copying numba\testing\__init__.py -> build\lib.win-amd64-cpython-310\numba\testing
#   copying numba\testing\__main__.py -> build\lib.win-amd64-cpython-310\numba\testing
#   creating build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\annotation_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\cache_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\cffi_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\cfunc_cache_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\compile_with_pycc.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\complex_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\ctypes_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\dummy_module.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\enum_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\error_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\inlining_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\jitclass_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\matmul_usecase.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\orphaned_semaphore_usecase.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\overload_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\parfors_cache_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\pdlike_usecase.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\recursion_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\serialize_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\support.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_alignment.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_analysis.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_annotations.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_api.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_array_analysis.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_array_attr.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_array_constants.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_array_exprs.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_array_iterators.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_array_manipulation.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_array_methods.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_array_reductions.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_array_return.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_auto_constants.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_blackscholes.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_buffer_protocol.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_builtins.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_caching.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_casting.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_cffi.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_cfunc.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_cgutils.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_chained_assign.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_cli.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_closure.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_codegen.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_compiler_lock.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_compile_cache.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_complex.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_comprehension.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_config.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_conversion.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_copy_propagate.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_ctypes.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_dataflow.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_datamodel.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_debug.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_debuginfo.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_del.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_deprecations.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_dictimpl.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_dictobject.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_dicts.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_dispatcher.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_dummyarray.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_dyn_array.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_dyn_func.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_entrypoints.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_enums.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_errorhandling.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_errormodels.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_exceptions.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_extended_arg.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_extending.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_extending_types.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_fancy_indexing.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_fastmath.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_flow_control.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_func_interface.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_func_lifetime.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_gdb.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_generators.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_gil.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_globals.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_hashing.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_heapq.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_help.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_import.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_indexing.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_inlining.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_interproc.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_intwidth.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_ir.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_ir_inlining.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_ir_utils.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_itanium_mangler.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_iteration.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_jitclasses.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_jitmethod.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_jit_module.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_linalg.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_listimpl.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_listobject.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_lists.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_literal_dispatch.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_llvm_version_check.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_locals.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_looplifting.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_mandelbrot.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_mangling.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_mathlib.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_maxmin.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_multi3.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_nan.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_nested_calls.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_npdatetime.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_np_functions.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_nrt.py -> build\lib.win-amd64-cpython-310\numba\tests
# ...
#   copying numba\tests\test_typeof.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_types.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_typingerror.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_ufuncs.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_unicode.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_unicode_array.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_unicode_literals.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_unicode_names.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_unpack_sequence.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_unsafe_intrinsics.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_utils.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_vectorization_type_inference.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_warnings.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_withlifting.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\test_wrapper.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\threading_backend_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\timsort.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\true_div_usecase.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\usecases.py -> build\lib.win-amd64-cpython-310\numba\tests
#   copying numba\tests\__init__.py -> build\lib.win-amd64-cpython-310\numba\tests
#   creating build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\cache_usecases.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_caching.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_dufunc.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_errors.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_gufunc.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_parallel_env_variable.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_parallel_low_work.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_parallel_ufunc_issues.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_ufunc.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_ufuncbuilding.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\test_vectorize_decor.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   copying numba\tests\npyufunc\__init__.py -> build\lib.win-amd64-cpython-310\numba\tests\npyufunc
#   creating build\lib.win-amd64-cpython-310\numba\typeconv
#   copying numba\typeconv\castgraph.py -> build\lib.win-amd64-cpython-310\numba\typeconv
#   copying numba\typeconv\rules.py -> build\lib.win-amd64-cpython-310\numba\typeconv
#   copying numba\typeconv\typeconv.py -> build\lib.win-amd64-cpython-310\numba\typeconv
#   copying numba\typeconv\__init__.py -> build\lib.win-amd64-cpython-310\numba\typeconv
#   creating build\lib.win-amd64-cpython-310\numba\typed
#   copying numba\typed\typeddict.py -> build\lib.win-amd64-cpython-310\numba\typed
#   copying numba\typed\typedlist.py -> build\lib.win-amd64-cpython-310\numba\typed
#   copying numba\typed\__init__.py -> build\lib.win-amd64-cpython-310\numba\typed
#   creating build\lib.win-amd64-cpython-310\numba\types
#   copying numba\types\abstract.py -> build\lib.win-amd64-cpython-310\numba\types
#   copying numba\types\common.py -> build\lib.win-amd64-cpython-310\numba\types
#   copying numba\types\containers.py -> build\lib.win-amd64-cpython-310\numba\types
#   copying numba\types\functions.py -> build\lib.win-amd64-cpython-310\numba\types
#   copying numba\types\iterators.py -> build\lib.win-amd64-cpython-310\numba\types
#   copying numba\types\misc.py -> build\lib.win-amd64-cpython-310\numba\types
#   copying numba\types\npytypes.py -> build\lib.win-amd64-cpython-310\numba\types
#   copying numba\types\scalars.py -> build\lib.win-amd64-cpython-310\numba\types
#   copying numba\types\__init__.py -> build\lib.win-amd64-cpython-310\numba\types
#   creating build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\arraydecl.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\bufproto.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\builtins.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\cffi_utils.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\cmathdecl.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\collections.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\context.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\ctypes_utils.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\dictdecl.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\enumdecl.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\listdecl.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\mathdecl.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\npdatetime.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\npydecl.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\randomdecl.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\setdecl.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\templates.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\typeof.py -> build\lib.win-amd64-cpython-310\numba\typing
#   copying numba\typing\__init__.py -> build\lib.win-amd64-cpython-310\numba\typing
#   creating build\lib.win-amd64-cpython-310\numba\unsafe
#   copying numba\unsafe\bytes.py -> build\lib.win-amd64-cpython-310\numba\unsafe
#   copying numba\unsafe\ndarray.py -> build\lib.win-amd64-cpython-310\numba\unsafe
#   copying numba\unsafe\nrt.py -> build\lib.win-amd64-cpython-310\numba\unsafe
#   copying numba\unsafe\numbers.py -> build\lib.win-amd64-cpython-310\numba\unsafe
#   copying numba\unsafe\refcount.py -> build\lib.win-amd64-cpython-310\numba\unsafe
#   copying numba\unsafe\tuple.py -> build\lib.win-amd64-cpython-310\numba\unsafe
#   copying numba\unsafe\__init__.py -> build\lib.win-amd64-cpython-310\numba\unsafe
#   copying numba\mviewbuf.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_dispatcher.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_dynfunc.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_dynfuncmod.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_hashtable.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_helperlib.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_helpermod.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_lapack.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_math_c99.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_npymath_exports.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_random.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_typeof.c -> build\lib.win-amd64-cpython-310\numba
#   copying numba\capsulethunk.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\mathnames.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_arraystruct.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_dispatcher.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_hashtable.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_math_c99.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_numba_common.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_pymodule.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_typeof.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\_unicodetype_db.h -> build\lib.win-amd64-cpython-310\numba
#   copying numba\annotations\template.html -> build\lib.win-amd64-cpython-310\numba\annotations
#   copying numba\cext\dictobject.c -> build\lib.win-amd64-cpython-310\numba\cext
#   copying numba\cext\listobject.c -> build\lib.win-amd64-cpython-310\numba\cext
#   copying numba\cext\utils.c -> build\lib.win-amd64-cpython-310\numba\cext
#   copying numba\cext\cext.h -> build\lib.win-amd64-cpython-310\numba\cext
#   copying numba\cext\dictobject.h -> build\lib.win-amd64-cpython-310\numba\cext
#   copying numba\cext\listobject.h -> build\lib.win-amd64-cpython-310\numba\cext
#   copying numba\cuda\tests\cudadrv\data\jitlink.ptx -> build\lib.win-amd64-cpython-310\numba\cuda\tests\cudadrv\data
#   copying numba\pycc\modulemixin.c -> build\lib.win-amd64-cpython-310\numba\pycc
#   copying numba\runtime\nrt.c -> build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\runtime\_nrt_python.c -> build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\runtime\_nrt_pythonmod.c -> build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\runtime\nrt.h -> build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\runtime\nrt_external.h -> build\lib.win-amd64-cpython-310\numba\runtime
#   copying numba\targets\cmdlang.gdb -> build\lib.win-amd64-cpython-310\numba\targets
#   creating build\lib.win-amd64-cpython-310\numba\tests\pycc_distutils_usecase
#   copying numba\tests\pycc_distutils_usecase\setup_distutils.py -> build\lib.win-amd64-cpython-310\numba\tests\pycc_distutils_usecase
#   copying numba\tests\pycc_distutils_usecase\setup_setuptools.py -> build\lib.win-amd64-cpython-310\numba\tests\pycc_distutils_usecase
#   copying numba\tests\pycc_distutils_usecase\source_module.py -> build\lib.win-amd64-cpython-310\numba\tests\pycc_distutils_usecase
#   running build_ext
#   INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   building 'numba._dynfunc' extension
#   creating build\temp.win-amd64-cpython-310
#   creating build\temp.win-amd64-cpython-310\Release
#   creating build\temp.win-amd64-cpython-310\Release\numba
#   INFO: C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\Users\martin.roelfs\Anaconda3\envs\teahouse\include -IC:\Users\martin.roelfs\Anaconda3\envs\teahouse\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\ATLMFC\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\cppwinrt /Tcnumba/_dynfuncmod.c /Fobuild\temp.win-amd64-cpython-310\Release\numba\_dynfuncmod.obj -g
#   cl : Command line warning D9002 : ignoring unknown option '-g'
#   INFO: C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:C:\Users\martin.roelfs\Anaconda3\envs\teahouse\libs /LIBPATH:C:\Users\martin.roelfs\Anaconda3\envs\teahouse /LIBPATH:C:\Users\martin.roelfs\Anaconda3\envs\teahouse\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\ATLMFC\lib\x64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22000.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22000.0\um\x64 /EXPORT:PyInit__dynfunc build\temp.win-amd64-cpython-310\Release\numba\_dynfuncmod.obj /OUT:build\lib.win-amd64-cpython-310\numba\_dynfunc.cp310-win_amd64.pyd /IMPLIB:build\temp.win-amd64-cpython-310\Release\numba\_dynfunc.cp310-win_amd64.lib
#   building 'numba._dispatcher' extension
#   creating build\temp.win-amd64-cpython-310\Release\numba\typeconv
#   INFO: C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\\Users\\martin.roelfs\\Anaconda3\\envs\\teahouse\\lib\\site-packages\\numpy\\core\\include -IC:\Users\martin.roelfs\Anaconda3\envs\teahouse\include -IC:\Users\martin.roelfs\Anaconda3\envs\teahouse\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\ATLMFC\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\cppwinrt /Tcnumba/_dispatcher.c /Fobuild\temp.win-amd64-cpython-310\Release\numba\_dispatcher.obj
#   _dispatcher.c
#   numba/_dispatcher.c(26): error C2039: 'use_tracing': is not a member of '_ts'
#   C:\Users\martin.roelfs\Anaconda3\envs\teahouse\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   numba/_dispatcher.c(28): error C2039: 'use_tracing': is not a member of '_ts'
#   C:\Users\martin.roelfs\Anaconda3\envs\teahouse\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   numba/_dispatcher.c(199): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   numba/_dispatcher.c(301): error C2039: 'use_tracing': is not a member of '_ts'
#   C:\Users\martin.roelfs\Anaconda3\envs\teahouse\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   numba/_dispatcher.c(507): error C2039: 'use_tracing': is not a member of '_ts'
#   C:\Users\martin.roelfs\Anaconda3\envs\teahouse\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   numba/_dispatcher.c(517): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   error: Command "C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\\Users\\martin.roelfs\\Anaconda3\\envs\\teahouse\\lib\\site-packages\\numpy\\core\\include -IC:\Users\martin.roelfs\Anaconda3\envs\teahouse\include -IC:\Users\martin.roelfs\Anaconda3\envs\teahouse\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\ATLMFC\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\cppwinrt /Tcnumba/_dispatcher.c /Fobuild\temp.win-amd64-cpython-310\Release\numba\_dispatcher.obj" failed with exit status 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numba
# ERROR: Could not build wheels for numba, which is required to install pyproject.toml-based projects

# %%
from kingdon import Algebra, MultiVector
import numpy as np
from numba import njit

alg = Algebra(4, 1, wrapper=njit)
locals().update(alg.blades)

# %% [markdown]
# In order to have a fair comparison, we make a full multivector, which prevents `kingdon` from using the sparseness of the input to gain additional performance benefits.

# %%
l1 = e145
l2 = e245
R = 1 + l2 * l1

# %% [markdown]
# The function we will optimize for this example is the conjugation (or sandwich product) used to transform a multivector $X$ by a rotor $R$:

# %%
def apply_rotor(R, X):
    return R * X * ~R

# %% [markdown]
# The first execution will be the most expensive, because it triggers the code generation for the geometric product and reversion operators to be performed. We therefore time it seperatelly:

# %%
# %timeit -n 1 -r 1 apply_rotor(R, l1)
# Out:
# 404 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# We can now time the actual excecution time of the `apply_rotor` function.

# %%
# %timeit -n 10_000 -r 10 apply_rotor(R, l1)
# Out:
# 66 µs ± 28.3 µs per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# We now have a benchmark: to perform the function `apply_rotor` takes about 7.69 µs ± 59.2 ns on the authors laptop. To do better is easy: we simply apply the `Algebra.register` decorator to `apply_rotor`:
# ```python
# @alg.register
# def apply_rotor(R, X):
#     return R * X * ~R
# ```
# This decorator allows `kingdon` to work its magic on the decorated function.
# While the decorator syntax is pleasant to look it, it overwrites the original function, so in this document we are better off using
# ```python
# apply_rotor_compiled = alg.register(apply_rotor)
# ```

# %%
apply_rotor_compiled = alg.register(apply_rotor)

# %%
# %timeit -n 1 -r 1 apply_rotor_compiled(R, l1)
# Out:
# 703 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %timeit -n 10_000 -r 10 apply_rotor_compiled(R, l1)
# Out:
# 36.5 µs ± 7.14 µs per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# After decoration the code runs in about 3.87 µs ± 529 ns on the authors laptop, which is roughly a two-fold improvement in performance. Not bad, for so little effort. The reason for the speed-up is that ordinarilly kingdon has to traverse down to the actual numerical implementation from the python level and then back up for every operator. So in this example this is done three times: two times for the products `*`, and once for the reversion `~`.
#
# By contrast, the `Algebra.register` decorator only traverses down to the numerical level once, does all the computations on that level, and then passes the results back up the chain.
#
# Having had our first taste of better performance, we of course want to know if we can do even better. In this example we would expect that we can get a better result if we first do some symbolical symplification, since both $R$ and $\widetilde{R}$ appear in the expression. We can ask the decorator to do symbolic symplification by instead using
#
# ```python
# @alg.register(symbolic=True)
# def apply_rotor(R, X):
#     return R * X * ~R
# ```
#
# (Note: for more complicated expressions this might be a bad idea, since symbolic symplification can get very expensive.)

# %%
apply_rotor_simplified = alg.register(apply_rotor, symbolic=True)

# %%
# %timeit -n 1 -r 1 apply_rotor_simplified(R, l1)
# Out:
# 1.02 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %timeit -n 10_000 -r 10 apply_rotor_simplified(R, l1)
# Out:
# 28.1 µs ± 6.01 µs per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# The symbolical optimization is more expensive to perform, even in this sparse example. However, we do obtain a new speed record: 1.91 µs ± 376 ns, which is ~4 times faster than the original.
#
# Of course conjugation is a common operation, so `kingdon` does ship with a precompiled version. The operator for conjugation is given by `>>`:

# %%
# %timeit -n 1 -r 1 R >> l1
# Out:
# 472 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %timeit -n 10_000 -r 10 R >> l1
# Out:
# 34.4 µs ± 6.69 µs per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# This has comparable numerical performance and also has a shorter generation time, which is important for the user experience.
#
# We have now achieved the limit of what can be achieved with the `@alg.register` decorator: 1.91 µs ± 376 ns, a four-fold speed-up compared to the undecorated version. Beware however, that until we can find a faster symbolic engine than `sympy`, it is usually a bad idea to use the `symbolic` keyword. It is therefore recommended to only use the `symbolic` keyword selectly.

# %% [markdown]
# ### Clifford
#
# Now let us repeat these exercises, but using [`clifford`](https://clifford.readthedocs.io/en/latest/tutorials/PerformanceCliffordTutorial.html).

# %%
import clifford as cf
from clifford import g3c
import numba

# Get the layout in our local namespace etc etc
layout = g3c.layout
locals().update(g3c.blades)

ep, en, up, down, homo, E0, ninf, no = (g3c.stuff["ep"], g3c.stuff["en"],
                                        g3c.stuff["up"], g3c.stuff["down"], g3c.stuff["homo"],
                                        g3c.stuff["E0"], g3c.stuff["einf"], -g3c.stuff["eo"])
# Define a few useful terms
E = ninf^(no)
I5 = e12345
I3 = e123
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import clifford as cf
#       2 from clifford import g3c
#       3 import numba
#
# File ~\Anaconda3\envs\teahouse\lib\site-packages\clifford\__init__.py:95
#      92 from clifford.io import write_ga_file, read_ga_file  # noqa: F401
#      94 from ._version import __version__  # noqa: F401
# ---> 95 from . import _numba_utils
#      97 from ._settings import pretty, ugly, eps, print_precision  # noqa: F401
#      98 import clifford.taylor_expansions as taylor_expansions
#
# File ~\Anaconda3\envs\teahouse\lib\site-packages\clifford\_numba_utils.py:85
#      83 if not DISABLE_JIT:
#      84     njit = numba.njit
# ---> 85     generated_jit = numba.generated_jit
#      86 else:
#      87     def njit(f=None, **kwargs):
#
# AttributeError: module 'numba' has no attribute 'generated_jit'

# %%
def cf_apply_rotor(R,mv):
    return R*mv*~R

# %%
line_one = (up(0)^up(e1)^ninf).normal()
line_two = (up(0)^up(e2)^ninf).normal()
R = 1 + line_two*line_one

# %%
# %timeit -n 1 -r 1 cf_apply_rotor(R, line_one)
# %timeit -n 10_000 -r 10 cf_apply_rotor(R, line_one)

# %% [markdown]
# The default `clifford` version of the conjugation formula takes 9.14 µs ± 55.6 ns on the authors laptop. In order to improve performance, we need to reach into the internals of `clifford`, and explicitelly call the relevant functions. This means that to speed-up the code, one has to be an advanced user.

# %%
def cf_apply_rotor_faster(R,mv):
    return layout.MultiVector(layout.gmt_func(R.value,layout.gmt_func(mv.value,layout.adjoint_func(R.value))) )

# %%
# %timeit -n 1 -r 1 cf_apply_rotor_faster(R, line_one)
# %timeit -n 10_000 -r 10 cf_apply_rotor_faster(R, line_one)

# %% [markdown]
# The result is very good: about a two-fold speed-up to 4.95 µs ± 698 ns on the authors laptop.
#
# We can improve this further by adding the `numba.njit` decorator to our function:

# %%
gmt_func = layout.gmt_func
adjoint_func = layout.adjoint_func

@numba.njit
def cf_apply_rotor_val_numba(R_val,mv_val):
    return gmt_func(R_val, gmt_func(mv_val, adjoint_func(R_val)))

def cf_apply_rotor_wrapped_numba(R,mv):
    return cf.MultiVector(layout, cf_apply_rotor_val_numba(R.value, mv.value))

# %%
# %timeit -n 1 -r 1 cf_apply_rotor_wrapped_numba(R, line_one)
# %timeit -n 10_000 -r 10 cf_apply_rotor_wrapped_numba(R, line_one)

# %% [markdown]
# We are now down to 3.52 µs ± 403 ns per loop on the authors laptop, a ~2.6 times increase. These times however are very comparible to the 3.87 µs ± 529 ns we got from the `@alg.register` decorator, which looked like this:
# ```python
# @alg.register
# def apply_rotor(R, X):
#     return R * X * ~R
# ```
# So with a much cleaner API, we can achieve similar results in `kingdon`.

# %% [markdown]
# ### King on a Leash
#
# In order to have a fair comparison, we will end with a computation in kingdon on a full multivector. This means `kingdon` will not be able to cheat by doing almost no computations in the first place, and will really have to multiply full multivectors, just like `clifford`.

# %%
from kingdon import Algebra, MultiVector
import numpy as np

alg = Algebra(4, 1, wrapper=njit)
locals().update(alg.blades)

# %%
l1vals = np.zeros(len(alg))
l2vals = np.zeros(len(alg))
l1 = alg.multivector(l1vals) + e145
l2 = alg.multivector(l2vals) + e245
R = 1 + l2 * l1

# %%
def apply_rotor(R, X):
    return R * X * ~R

# %%
# %timeit -n 1 -r 1 apply_rotor(R, l1)
# %timeit -n 10_000 -r 10 apply_rotor(R, l1)

# %% [markdown]
# On a full multivector, `kingdon` takes 18 µs ± 696 ns per loop on the authors laptop. This is significantly more than the 7.69 µs ± 59.2 ns for the sparse scenario, and also more than the 9.14 µs ± 55.6 ns delivered by `clifford`. However, we can fix this in one simple move:

# %%
apply_rotor_compiled = alg.register(apply_rotor)

# %%
# %timeit -n 1 -r 1 apply_rotor_compiled(R, l1)
# %timeit -n 10_000 -r 10 apply_rotor_compiled(R, l1)

# %% [markdown]
# With one decorator, we are down to 5.59 µs ± 724 ns per loop, which is close to the 3.52 µs ± 403 ns that `clifford` achieves with much more manual labour on the part of the programmer. (We will not include the `symbolic=True` version here, because for a full multivector this will be way to expensive.)
#
# Most of the costs that both `clifford` and `kingdon` make is in the glue around the computation.
# This is responsable for part of the speed-up in the `clifford` code, and we haven't tapped into this yet in the `kingdon` example so far.
# So if you are willing to compromise readability, `kingdon` can still do a little bit better by removing the glue:

# %%
def apply_rotor_numba(R, X):
    keys_out, func = apply_rotor_compiled[R.keys(), X.keys()]
    numba_func = alg.numspace[func.__name__]  # The numba version is available from the namespace of numerical functions; numspace.
    return MultiVector.fromkeysvalues(
        alg, 
        keys=keys_out, 
        values=numba_func(R.values(), X.values()),
    )

# %% [markdown]
# The decorated function `apply_rotor_compiled` can be accessed like a dictionary to retrieve the numerical function and the resulting `keys_out` for the input `keys` of `R` and `l1`. Moreover, the alternative constructor `MultiVector.fromkeysvalues` bypasses the sanity checking of the default constructor so as to reach optimal performance. We then simply have to make a function to return the result back into

# %%
# %timeit -n 1 -r 1 apply_rotor_numba(R, l1)

# %%
# %timeit -n 10_000 -r 10 apply_rotor_numba(R, l1)

# %% [markdown]
# We now see that the `kingdon` function is also faster than the `clifford` version in the full multivector version, with 2.91 µs ± 16.3 ns for `kingdon` vs. 3.52 µs ± 403 ns for `clifford`. Putting the `kingdon` decorator on a diet to reach this limit is an ongoing effort.

# %% [markdown]
# ## Conclusion
# For full multivectors, clifford is still a bit faster than `kingdon`'s `Algebra.register` decorator, but at the cost of readability. And as we have seen, `kingdon` can match this performance and lack of readability if needed. However, in reality many multivectors are not full, but rather of only a select number of grades, or even just a couple of coefficients. In these scenarios, `kingdon` really comes into its own, and the very readable `Algebra.register` decorator offers a way to achieve high performance for very little effort on the users part.
